# %% [markdown]
# #### Adding data to MongoDB atlas

# %%
from pymongo import MongoClient

client = MongoClient("mongodb+srv://sarkarshreejoy30:sarkar.s30@cluster0.qytku.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0")

db = client['cryto_price']
collection = db['price']

import pandas as pd
df = pd.read_csv("btc-usd-max.csv")

data = df.to_dict(orient='records')
collection.insert_many(data)
# Out:
# InsertManyResult([ObjectId('66feb09b603d1abe323f6599'), ObjectId('66feb09b603d1abe323f659a'), ObjectId('66feb09b603d1abe323f659b'), ObjectId('66feb09b603d1abe323f659c'), ObjectId('66feb09b603d1abe323f659d'), ObjectId('66feb09b603d1abe323f659e'), ObjectId('66feb09b603d1abe323f659f'), ObjectId('66feb09b603d1abe323f65a0'), ObjectId('66feb09b603d1abe323f65a1'), ObjectId('66feb09b603d1abe323f65a2'), ObjectId('66feb09b603d1abe323f65a3'), ObjectId('66feb09b603d1abe323f65a4'), ObjectId('66feb09b603d1abe323f65a5'), ObjectId('66feb09b603d1abe323f65a6'), ObjectId('66feb09b603d1abe323f65a7'), ObjectId('66feb09b603d1abe323f65a8'), ObjectId('66feb09b603d1abe323f65a9'), ObjectId('66feb09b603d1abe323f65aa'), ObjectId('66feb09b603d1abe323f65ab'), ObjectId('66feb09b603d1abe323f65ac'), ObjectId('66feb09b603d1abe323f65ad'), ObjectId('66feb09b603d1abe323f65ae'), ObjectId('66feb09b603d1abe323f65af'), ObjectId('66feb09b603d1abe323f65b0'), ObjectId('66feb09b603d1abe323f65b1'), ObjectId('66feb09b603d1abe323f
# ...

# %% [markdown]
# #### Calling the data directly from mongodb atlas and storing in .csv file

# %%
document = list(collection.find_one())
raw_data = pd.DataFrame(document)
df.to_csv('raw data.csv',index=False)

# %%
price_data = pd.read_csv('raw data.csv')

# %%
price_data.tail()
# Out:
#                    snapped_at         price    market_cap  total_volume
# 4167  2024-09-26 00:00:00 UTC  63151.899594  1.245721e+12  2.608764e+10
# 4168  2024-09-27 00:00:00 UTC  65130.768840  1.287151e+12  3.799557e+10
# 4169  2024-09-28 00:00:00 UTC  65791.002125  1.299708e+12  3.266492e+10
# 4170  2024-09-29 00:00:00 UTC  65934.107094  1.303218e+12  1.534291e+10
# 4171  2024-09-30 00:00:00 UTC  65663.689867  1.297826e+12  1.294871e+10
